# %%
pip install -e ..
# Out:
# Obtaining file:///workspaces/Chemcell
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for chemcell (pyproject.toml) ... done
#   Created wheel for chemcell: filename=chemcell-0.2.4-0.editable-py3-none-any.whl size=4768 sha256=00d87faf3571f01a9e92b1a3c5125fbe5630a5765f64033b48a88cfdc57d72c1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-17e41fnt/wheels/26/9b/11/bba1d96a7b44eaa3400a65f6e4809477877dd8bc3d5204fb12
# Successfully built chemcell
# ...
#   Attempting uninstall: chemcell
#     Found existing installation: chemcell 0.2.4
#     Uninstalling chemcell-0.2.4:
#       Successfully uninstalled chemcell-0.2.4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import csv

# %%
file = open("/workspaces/Chemcell/Example_Data/Ouput_Data_['Hcl', None, None, None].csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 file = open("/workspaces/Chemcell/Example_Data/Ouput_Data_['Hcl', None, None, None].csv")
#
# File ~/.local/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: "/workspaces/Chemcell/Example_Data/Ouput_Data_['Hcl', None, None, None].csv"

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

df1 = pd.read_csv("/workspaces/Chemcell/Study/Data/Output_Data_['Methane'].csv")
df2 = pd.read_csv("/workspaces/Chemcell/Study/Data/Output_Data_['HCl'].csv")
df3 = pd.read_csv("/workspaces/Chemcell/Study/Data/Output_Data_['C4H8O2'].csv")
df4 = pd.read_csv("/workspaces/Chemcell/Study/Data/Output_Data_['C4H8'].csv")
df5 = pd.read_csv("/workspaces/Chemcell/Study/Data/Output_Data_['Butane'].csv")

df1

#d.values
#d = d.drop(["Reactant_Name_1", "Reactant_ID_1", "Reactant_Name_2", "Reactant_ID_2", "Product_Name_1", "Product_ID_1", "Product_Name_2", "Product_ID_2"], axis=1)
# Out:
#     Reactant_Count  Product_Count  \
# 0                2              1
# 1                1              2
# 2                2              1
# 3                2              2
# 4                2              2
# 5                2              1
# 6                2              1
# 7                2              2
# 8                2              1
# 9                2              2
# 10               2              2
# 11               1              2
# 12               1              2
# 13               1              2
# 14               2              1
# 15               2              2
# 16               3              3
# 17               1              2
# 18               1              2
# 19               1              2
# 20               1              2
# 21               2              1
# 22               2              2
# 23               1              2
# 24               1              2
# 25               1              2
# ...

# %%
from chemcell import Chemcell as Chc
example = Chc(["H2O", "HCl"], False, "/workspaces/Chemcell/Example_Data").range(0,12).tabulate()
# Out:
# 2024-09-29 05:02:29,779 - chemcell - INFO - Initialising Chemcell with ['H2O', 'HCl'], Keep outliers: False, file_location: /workspaces/Chemcell/Example_Data
# 2024-09-29 05:02:29,783 - chemcell - INFO - Starting Bulk data buildup
# 2024-09-29 05:02:30,998 - chemcell - INFO - r_min: 0, r_max: 12, total_mixture: 1
# 2024-09-29 05:02:30,999 - chemcell - WARNING - r_Max was either none or larger than total, assumed and defaulted to max value
# 2024-09-29 05:02:31,001 - chemcell - WARNING - BEGINNING PROCESS SINGLE MIXTURE: FAILED
# Data shown is not fullilling criteria ['[Sn(Me)3]3(N)', 'Hydrogen chloride', 'Water', 'Water', 'Ammonium Chloride', 'Water', 'Sn(Me)3(OH)'] Could be due to passing the R_count, P_count
# 2024-09-29 05:02:31,002 - chemcell - WARNING - Mixture 1/1 did not yield results
# 2024-09-29 05:02:31,002 - chemcell - INFO - Processing mixture: 1/1 ( 100.00%)
# 2024-09-29 05:02:31,003 - chemcell - INFO -
# Processed 0 mixtures successfully out of 1 attempted.
# ...

# %%
print(example)
# Out:
# No data given, changing to: /workspaces/Chemcell/Example_Data/Ouput_Data_['H2O', 'Cl'].csv
