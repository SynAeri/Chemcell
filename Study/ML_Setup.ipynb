# %%
pip install seaborn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 2.4 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 5.9 MB/s eta 0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 45.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.2/323.2 kB 7.9 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 31.1 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 8.4 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 52.3 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 2.6 MB/s eta 0:00:00:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import csv
import seaborn as sb

# %%
file = open("/workspaces/Organicle/Example_Data/Ouput_Data.csv")
# Out:
# Reactant_Count,Product_Count,"['Reactant_Name_1', 'Reactant_ID_1']","['Electron affinity', 'Ionization energy', 'Critical Pressure', 'Dipole Moment', 'Molar entropy at standard cconditions (1 bar)', 'Solid phase molar entropy at standard conditions', 'Normal Boiling Point Temperature', 'Critical Temperature', 'Critical Volume', 'Enthalpy of formation at standard conditions', 'MolecularWeight', 'RotatableBondCount', 'DefinedBondStereoCount', 'Complexity', 'HBondDonorCount', 'HBondAcceptorCount', 'Complexity', 'CovalentUnitCount', 'Charge', 'HeavyAtomCount', 'IsotopeAtomCount']","['Reactant_Name_2', 'Reactant_ID_2']","['Electron affinity', 'Ionization energy', 'Critical Pressure', 'Dipole Moment', 'Molar entropy at standard cconditions (1 bar)', 'Solid phase molar entropy at standard conditions', 'Normal Boiling Point Temperature', 'Critical Temperature', 'Critical Volume', 'Enthalpy of formation at standard conditions', 'MolecularWeight', 'RotatableBondCount', 'DefinedBondStereoCount'
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

d = pd.read_csv("/workspaces/Organicle/Example_Data/Ouput_Data_HCl.csv")
#d.values
d = d.drop(["Reactant_Name_1", "Reactant_ID_1", "Reactant_Name_2", "Reactant_ID_2", "Product_Name_1", "Product_ID_1", "Product_Name_2", "Product_ID_2"], axis=1)
d.corr()
# Out:
#                           Reactant_Count  Product_Count  Electron affinity  \
# Reactant_Count                       NaN            NaN                NaN
# Product_Count                        NaN            NaN                NaN
# Electron affinity                    NaN            NaN                NaN
# Ionization energy                    NaN            NaN                NaN
# Critical Pressure                    NaN            NaN                NaN
# Dipole Moment                        NaN            NaN                NaN
# Critical Temperature                 NaN            NaN                NaN
# MolecularWeight                      NaN            NaN                NaN
# RotatableBondCount                   NaN            NaN                NaN
# DefinedBondStereoCount               NaN            NaN                NaN
# Complexity                           NaN            NaN                NaN
# ...
