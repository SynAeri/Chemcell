# %%
pip install numpy
pip install pandas
# Out:
#   Cell In[3], line 1
#     pip install numpy
#         ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd
import csv

# %%
file = open("/workspaces/Organicle/Example_Data/Ouput_Data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 file = open("/workspaces/Organicle/Example_Data/Ouput_Data.csv")
#
# File /workspaces/Chemcell/.conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/workspaces/Organicle/Example_Data/Ouput_Data.csv'

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

d = pd.read_csv("/workspaces/Chemcell/Example_Data/Ouput_Data_Hcl.csv")
#d.values
#d = d.drop(["Reactant_Name_1", "Reactant_ID_1", "Reactant_Name_2", "Reactant_ID_2", "Product_Name_1", "Product_ID_1", "Product_Name_2", "Product_ID_2"], axis=1)
d
# Out:
#    Reactant_Count  Product_Count Reactant_Name_1 Reactant_ID_1  \
# 0               2              2        Phosgene       75-44-5
# 1               2              2        Phosgene       75-44-5
# 2               2              2        Phosgene       75-44-5
# 3               2              2        Phosgene       75-44-5
#
#    Electron affinity  Ionization energy  Critical Pressure  Dipole Moment  \
# 0              98.91                  0                  0             29
# 1              98.91                  0                  0             29
# 2              98.91                  0                  0             29
# 3              98.91                  0                  0             29
#
#    Critical Temperature  Octanol/Water partition coefficient  MolecularWeight  \
# 0                     0                                    1               29
# 1                     0                                    1               29
# 2                     0                                    1               29
# 3                     0                                    1               29
#
#    RotatableBondCount  DefinedBondStereoCount  Complexity  HBondDonorCount  \
# 0                   1                       0           4                0
# 1                   1                       0           4                0
# 2                   1                       0           4                0
# 3                   1                       0           4                0
#
#   HBondAcceptorCount Complexity.1  CovalentUnitCount  Charge  HeavyAtomCount  \
# 0              Water    7732-18-5             18.015       0               0
# 1              Water    7732-18-5             18.015       0               0
# 2              Water    7732-18-5             18.015       0               0
# 3              Water    7732-18-5             18.015       0               0
#
#    IsotopeAtomCount  Reactant_Name_2  Reactant_ID_2  Electron affinity.1  \
# 0                 0                1              1                    0
# 1                 0                1              1                    0
# 2                 0                1              1                    0
# 3                 0                1              1                    0
#
#    Ionization energy.1  Critical Pressure.1  Dipole Moment.1  \
# 0                    1                    0                1
# 1                    1                    0                1
# 2                    1                    0                1
# 3                    1                    0                1
#
#    Critical Temperature.1 Octanol/Water partition coefficient.1  \
# 0                       0                        Carbon dioxide
# 1                       0                        Carbon dioxide
# 2                       0                        Carbon dioxide
# 3                       0                        Carbon dioxide
#
#   MolecularWeight.1  RotatableBondCount.1  DefinedBondStereoCount.1  \
# 0          124-38-9                44.009                         0
# 1          124-38-9                44.009                         0
# 2          124-38-9                44.009                         0
# 3          124-38-9                44.009                         0
#
#    Complexity.2  HBondDonorCount.1  HBondAcceptorCount.1  Complexity.3  \
# 0             0                 18                     0             2
# 1             0                 18                     0             2
# 2             0                 18                     0             2
# 3             0                 18                     0             2
#
#    CovalentUnitCount.1  Charge.1  HeavyAtomCount.1  IsotopeAtomCount.1  \
# 0                   18         1                 0                   3
# 1                   18         1                 0                   3
# 2                   18         1                 0                   3
# 3                   18         1                 0                   3
#
#    Product_Name_1       Product_ID_1 Electron affinity.2  Ionization energy.2  \
# 0               0  Hydrogen chloride           7647-01-0                36.46
# 1               0  Hydrogen chloride           7647-01-0                36.46
# 2               0  Hydrogen chloride           7647-01-0                36.46
# 3               0  Hydrogen chloride           7647-01-0                36.46
#
#    Critical Pressure.2  Dipole Moment.2  Critical Temperature.2  \
# 0                    0                0                       0
# 1                    0                0                       0
# 2                    0                0                       0
# 3                    0                0                       0
#
#    Octanol/Water partition coefficient.2  MolecularWeight.2  \
# 0                                      1                  0
# 1                                      1                  0
# 2                                      1                  0
# 3                                      1                  0
#
#    RotatableBondCount.2  DefinedBondStereoCount.2  Complexity.4  \
# 0                     0                         1             0
# 1                     0                         1             0
# 2                     0                         1             0
# 3                     0                         1             0
#
#    HBondDonorCount.2  HBondAcceptorCount.2  Complexity.5  CovalentUnitCount.2  \
# 0                  1                     0           NaN                  NaN
# 1                  1                     0           NaN                  NaN
# 2                  1                     0           NaN                  NaN
# 3                  1                     0           NaN                  NaN
#
#    Charge.2  HeavyAtomCount.2  IsotopeAtomCount.2  Product_Name_2  \
# 0       NaN               NaN                 NaN             NaN
# 1       NaN               NaN                 NaN             NaN
# 2       NaN               NaN                 NaN             NaN
# 3       NaN               NaN                 NaN             NaN
#
#    Product_ID_2  Electron affinity.3  Ionization energy.3  \
# 0           NaN                  NaN                  NaN
# 1           NaN                  NaN                  NaN
# 2           NaN                  NaN                  NaN
# 3           NaN                  NaN                  NaN
#
#    Critical Pressure.3  Dipole Moment.3  Critical Temperature.3  \
# 0                  NaN              NaN                     NaN
# 1                  NaN              NaN                     NaN
# 2                  NaN              NaN                     NaN
# 3                  NaN              NaN                     NaN
#
#    Octanol/Water partition coefficient.3  MolecularWeight.3  \
# 0                                    NaN                NaN
# 1                                    NaN                NaN
# 2                                    NaN                NaN
# 3                                    NaN                NaN
#
#    RotatableBondCount.3  DefinedBondStereoCount.3  Complexity.6  \
# 0                   NaN                       NaN           NaN
# 1                   NaN                       NaN           NaN
# 2                   NaN                       NaN           NaN
# 3                   NaN                       NaN           NaN
#
#    HBondDonorCount.3  HBondAcceptorCount.3  Complexity.7  CovalentUnitCount.3  \
# 0                NaN                   NaN           NaN                  NaN
# 1                NaN                   NaN           NaN                  NaN
# 2                NaN                   NaN           NaN                  NaN
# 3                NaN                   NaN           NaN                  NaN
#
#    Charge.3  HeavyAtomCount.3  IsotopeAtomCount.3
# 0       NaN               NaN                 NaN
# 1       NaN               NaN                 NaN
# 2       NaN               NaN                 NaN
# 3       NaN               NaN                 NaN
