# %%
pip install numpy
pip install pandas
# Out:
#   Cell In[2], line 1
#     pip install numpy
#         ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd
import csv

# %%
file = open("/workspaces/Chemcell/Example_Data/Ouput_Data_['Hcl', None, None, None].csv")

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

d = pd.read_csv("/workspaces/Chemcell/Example_Data/Ouput_Data_['Hcl', None, None, None].csv")
#d.values
#d = d.drop(["Reactant_Name_1", "Reactant_ID_1", "Reactant_Name_2", "Reactant_ID_2", "Product_Name_1", "Product_ID_1", "Product_Name_2", "Product_ID_2"], axis=1)
d
# Out:
#    Reactant_Count  Product_Count   Reactant_Name_1 Reactant_ID_1  \
# 0               2              2          Phosgene       75-44-5
# 1               2              2          Phosgene       75-44-5
# 2               2              2          Phosgene       75-44-5
# 3               2              2          Phosgene       75-44-5
# 4               2              2  Trichloromethane       67-66-3
# 5               2              2  Trichloromethane       67-66-3
# 6               2              2  Trichloromethane       67-66-3
# 7               2              2  Trichloromethane       67-66-3
#
#    MolecularWeight  RotatableBondCount  DefinedBondStereoCount  Complexity  \
# 0            98.91                   0                       0          29
# 1            98.91                   0                       0          29
# 2            98.91                   0                       0          29
# 3            98.91                   0                       0          29
# ...
